# %% [markdown]
# # Exploratory Data Analysis of climate change

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (12,8)

# %%
data = pd.read_csv('climate-cleaned.csv')
data.head()
# Out:
#                        Timestamp          Location        Country  \
# 0  2000-01-01 00:00:00.000000000   New Williamtown         Latvia
# 1  2000-01-01 20:09:43.258325832      North Rachel   South Africa
# 2  2000-01-02 16:19:26.516651665  West Williamland  French Guiana
# 3  2000-01-03 12:29:09.774977497       South David        Vietnam
# 4  2000-01-04 08:38:53.033303330    New Scottburgh        Moldova
#
#    Temperature  CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# 0    10.688986     403.118903        0.717506      13.835237  23.631256
# 1    13.814430     396.663499        1.205715      40.974084  43.982946
# 2    27.323718     451.553155       -0.160783      42.697931  96.652600
# 3    12.309581     422.404983       -0.475931       5.193341  47.467938
# 4    13.210885     410.472999        1.135757      78.695280  61.789672
#
#    Wind Speed      Continent  day  month  year        date
# 0   18.492026         Europe    1      1  2000  2000-01-01
# ...

# %%
data.describe(include='all')
# Out:
#                             Timestamp     Location Country   Temperature  \
# count                           10000        10000   10000  10000.000000
# unique                          10000         7764     243           NaN
# top     2000-01-01 00:00:00.000000000  North David   Congo           NaN
# freq                                1           12      94           NaN
# mean                              NaN          NaN     NaN     14.936034
# std                               NaN          NaN     NaN      5.030616
# min                               NaN          NaN     NaN     -3.803589
# 25%                               NaN          NaN     NaN     11.577991
# 50%                               NaN          NaN     NaN     14.981136
# 75%                               NaN          NaN     NaN     18.305826
# max                               NaN          NaN     NaN     33.976956
#
#         CO2 Emissions  Sea Level Rise  Precipitation      Humidity  \
# ...

# %%
fig,ax = plt.subplots(3,2,figsize=(20,14))
plt.suptitle('Trend over years (2000-2022)')
sns.lineplot(x='year', y='Temperature',data=data, hue='Continent',style='Continent',ax=ax[0,0],ci=None)
sns.lineplot(x='year', y='CO2 Emissions',data=data, hue='Continent',style='Continent',ax=ax[0,1],ci=None)
sns.lineplot(x='year', y='Sea Level Rise',data=data, hue='Continent',style='Continent',ax=ax[1,0],ci=None)
sns.lineplot(x='year', y='Precipitation',data=data, hue='Continent',style='Continent',ax=ax[1,1],ci=None)
sns.lineplot(x='year', y='Humidity',data=data, hue='Continent',style='Continent',ax=ax[2,0],ci=None)
sns.lineplot(x='year', y='Wind Speed',data=data, hue='Continent',style='Continent',ax=ax[2,1],ci=None)
for i,ax in enumerate(fig.axes):
    ax.set(title='Average '+ax.get_ylabel().lower()+' change over years')
fig.tight_layout()

# %%
fig,ax = plt.subplots(3,2,figsize=(20,14))
plt.suptitle('Trend over years (2000-2022)')
sns.lineplot(x='month', y='Temperature',data=data, hue='Continent',style='Continent',ax=ax[0,0],ci=None)
sns.lineplot(x='month', y='CO2 Emissions',data=data, hue='Continent',style='Continent',ax=ax[0,1],ci=None)
sns.lineplot(x='month', y='Sea Level Rise',data=data, hue='Continent',style='Continent',ax=ax[1,0],ci=None)
sns.lineplot(x='month', y='Precipitation',data=data, hue='Continent',style='Continent',ax=ax[1,1],ci=None)
sns.lineplot(x='month', y='Humidity',data=data, hue='Continent',style='Continent',ax=ax[2,0],ci=None)
sns.lineplot(x='month', y='Wind Speed',data=data, hue='Continent',style='Continent',ax=ax[2,1],ci=None)
for i,ax in enumerate(fig.axes):
    ax.set(title='Average '+ax.get_ylabel().lower()+' by month')
fig.tight_layout()
