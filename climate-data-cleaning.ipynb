# %% [markdown]
# # Data Cleaning and Transforming

# %% [markdown]
# ## Extract data (import)

# %%
import pandas as pd
import numpy as np
import pycountry_convert as pc

# %%
raw_data = pd.read_csv('climate_change_data.csv')
raw_data.head()
# Out:
#                             Date          Location        Country  \
# 0  2000-01-01 00:00:00.000000000   New Williamtown         Latvia
# 1  2000-01-01 20:09:43.258325832      North Rachel   South Africa
# 2  2000-01-02 16:19:26.516651665  West Williamland  French Guiana
# 3  2000-01-03 12:29:09.774977497       South David        Vietnam
# 4  2000-01-04 08:38:53.033303330    New Scottburgh        Moldova
#
#    Temperature  CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# 0    10.688986     403.118903        0.717506      13.835237  23.631256
# 1    13.814430     396.663499        1.205715      40.974084  43.982946
# 2    27.323718     451.553155       -0.160783      42.697931  96.652600
# 3    12.309581     422.404983       -0.475931       5.193341  47.467938
# 4    13.210885     410.472999        1.135757      78.695280  61.789672
#
#    Wind Speed
# 0   18.492026
# 1   34.249300
# 2   34.124261
# 3    8.554563
# 4    8.001164

# %%
raw_data.describe(include='all')
# Out:
#                                  Date     Location Country   Temperature  \
# count                           10000        10000   10000  10000.000000
# unique                          10000         7764     243           NaN
# top     2000-01-01 00:00:00.000000000  North David   Congo           NaN
# freq                                1           12      94           NaN
# mean                              NaN          NaN     NaN     14.936034
# std                               NaN          NaN     NaN      5.030616
# min                               NaN          NaN     NaN     -3.803589
# 25%                               NaN          NaN     NaN     11.577991
# 50%                               NaN          NaN     NaN     14.981136
# 75%                               NaN          NaN     NaN     18.305826
# max                               NaN          NaN     NaN     33.976956
#
#         CO2 Emissions  Sea Level Rise  Precipitation      Humidity  \
# count    10000.000000    10000.000000   10000.000000  10000.000000
# unique            NaN             NaN            NaN           NaN
# top               NaN             NaN            NaN           NaN
# freq              NaN             NaN            NaN           NaN
# mean       400.220469       -0.003152      49.881208     49.771302
# std         49.696933        0.991349      28.862417     28.929320
# min        182.131220       -4.092155       0.010143      0.018998
# 25%        367.109330       -0.673809      24.497516     24.713250
# 50%        400.821324        0.002332      49.818967     49.678412
# 75%        433.307905        0.675723      74.524991     75.206390
# max        582.899701        4.116559      99.991900     99.959665
#
#           Wind Speed
# count   10000.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       25.082066
# std        14.466648
# min         0.001732
# 25%        12.539733
# 50%        24.910787
# 75%        37.670260
# max        49.997664

# %% [markdown]
# # Transform Data

# %% [markdown]
# ### Adding continent column to dataset by mapping country codes using pycountry-convert library

# %%
# Dictionary for mapping continent code to name
continentDict = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU': 'Europe'
}
# Mapping country by continent
continentlist=[]
for i in raw_data['Country']:
    try:
        country_code=pc.country_name_to_country_alpha2(i, cn_name_format="default") # convert country name to iso_code
        cont_code=pc.country_alpha2_to_continent_code(country_code) # convert iso_code to continent code
        cont_name=continentDict[cont_code] # convert continent code to name
    except KeyError:
        cont_name=None # Handler if the country name is not identified
    continentlist.append(cont_name)

# %%
print("length of list equal to the data shape =",len(continentlist)==raw_data.shape[0])
continentlist[:5]
# Out:
# length of list equal to the data shape = True
# ['Europe', 'Africa', 'South America', 'Asia', 'Europe']

# %%
# add continent column to dataframe
raw_data['Continent']=continentlist
raw_data.head()
# Out:
#                             Date          Location        Country  \
# 0  2000-01-01 00:00:00.000000000   New Williamtown         Latvia
# 1  2000-01-01 20:09:43.258325832      North Rachel   South Africa
# 2  2000-01-02 16:19:26.516651665  West Williamland  French Guiana
# 3  2000-01-03 12:29:09.774977497       South David        Vietnam
# 4  2000-01-04 08:38:53.033303330    New Scottburgh        Moldova
#
#    Temperature  CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# 0    10.688986     403.118903        0.717506      13.835237  23.631256
# 1    13.814430     396.663499        1.205715      40.974084  43.982946
# 2    27.323718     451.553155       -0.160783      42.697931  96.652600
# 3    12.309581     422.404983       -0.475931       5.193341  47.467938
# 4    13.210885     410.472999        1.135757      78.695280  61.789672
#
#    Wind Speed      Continent
# 0   18.492026         Europe
# 1   34.249300         Africa
# 2   34.124261  South America
# 3    8.554563           Asia
# 4    8.001164         Europe

# %%
raw_data.groupby('Continent').count()
# Out:
#                Date  Location  Country  Temperature  CO2 Emissions  \
# Continent
# Africa         2195      2195     2195         2195           2195
# Asia           2023      2023     2023         2023           2023
# Australia      1000      1000     1000         1000           1000
# Europe         1889      1889     1889         1889           1889
# North America  1471      1471     1471         1471           1471
# South America   594       594      594          594            594
#
#                Sea Level Rise  Precipitation  Humidity  Wind Speed
# Continent
# Africa                   2195           2195      2195        2195
# Asia                     2023           2023      2023        2023
# Australia                1000           1000      1000        1000
# Europe                   1889           1889      1889        1889
# North America            1471           1471      1471        1471
# South America             594            594       594         594

# %% [markdown]
# ### Handling country names that is not identified by the library

# %%
set(raw_data.loc[raw_data['Continent'].isna()]['Country'])
# Out:
# {'Antarctica (the territory South of 60 deg S)',
#  'Bouvet Island (Bouvetoya)',
#  'British Indian Ocean Territory (Chagos Archipelago)',
#  "Cote d'Ivoire",
#  'French Southern Territories',
#  'Heard Island and McDonald Islands',
#  'Holy See (Vatican City State)',
#  'Korea',
#  'Libyan Arab Jamahiriya',
#  'Netherlands Antilles',
#  'Palestinian Territory',
#  'Pitcairn Islands',
#  'Reunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Slovakia (Slovak Republic)',
#  'Svalbard & Jan Mayen Islands',
#  'Timor-Leste',
#  'United States Minor Outlying Islands',
#  'Western Sahara'}

# %% [markdown]
# Most of the country names that is not identified are islands/not a country. Some country names that is indeed a country are `Korea`, `Libyan Arab Jamahiriya` → `Libya`, `Cote d'Ivoire`, `Slovakia (Slovak Republic)` → `Slovakia`, `Timor-Leste`. I will map them manually since there is only 6 countries.

# %% [markdown]
# ### Mapping unidentified countries

# %%
raw_data.loc[raw_data['Country'].isin(['Korea','Timor-Leste','Palestinian Territory']), 'Continent']='Asia'
raw_data.loc[raw_data['Country'] == 'Slovakia (Slovak Republic)', 'Continent']='Europe'
raw_data.loc[raw_data['Country'].isin(["Cote d'Ivoire", 'Libyan Arab Jamahiriya']), 'Continent']='Africa'

# %%
set(raw_data.loc[raw_data['Continent'].isna()]['Country'])
# Out:
# {'Antarctica (the territory South of 60 deg S)',
#  'Bouvet Island (Bouvetoya)',
#  'British Indian Ocean Territory (Chagos Archipelago)',
#  'French Southern Territories',
#  'Heard Island and McDonald Islands',
#  'Holy See (Vatican City State)',
#  'Netherlands Antilles',
#  'Pitcairn Islands',
#  'Reunion',
#  'Saint Barthelemy',
#  'Saint Helena',
#  'Svalbard & Jan Mayen Islands',
#  'United States Minor Outlying Islands',
#  'Western Sahara'}

# %%
raw_data.loc[raw_data['Continent'].isna()]
# Out:
#                                Date       Location  \
# 5     2000-01-05 04:48:36.291629162   South Nathan
# 22    2000-01-19 11:33:51.683168316   East Darlene
# 29    2000-01-25 08:41:54.491449144    Williambury
# 37    2000-02-01 01:59:40.558055805   West Jeffrey
# 48    2000-02-10 07:46:36.399639964   Reynoldsberg
# ...                             ...            ...
# 9969  2022-12-05 19:08:22.250225024     Bakershire
# 9977  2022-12-12 12:26:08.316831616   Simmonsburgh
# 9983  2022-12-17 13:24:27.866786688  North Stephen
# 9986  2022-12-20 01:53:37.641764096       Johnview
# 9991  2022-12-24 06:42:13.933393280     Stevenside
#
#                                                 Country  Temperature  \
# 5                                          Saint Helena     6.229326
# 22                          French Southern Territories    21.082149
# 29                                              Reunion     8.940555
# 37    British Indian Ocean Territory (Chagos Archipe...    14.895743
# 48                                              Reunion     9.086153
# ...                                                 ...          ...
# 9969                                     Western Sahara    13.841512
# 9977                                            Reunion     8.040745
# 9983  British Indian Ocean Territory (Chagos Archipe...    15.763664
# 9986                                     Western Sahara     9.878773
# 9991                                            Reunion    21.597189
#
#       CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 5        392.473317        1.122210      76.368331  48.973886   30.398908
# 22       421.304289        0.236963      95.566283  87.701528   34.050236
# 29       398.027810       -0.733600      41.271330   7.689676   43.446416
# 37       474.318087        0.030541      46.626748   2.646945   20.247608
# 48       382.468520       -0.679688      36.860851  25.256477   26.707505
# ...             ...             ...            ...        ...         ...
# 9969     392.264074       -1.194432      55.543819  62.605059   35.589569
# 9977     471.626365        0.867123      56.003999  95.338273   42.129883
# 9983     435.153922        0.763351      11.269627  43.034142   18.590588
# 9986     506.129390       -1.508617      57.910260  94.057981   11.053514
# 9991     314.464280        0.340999      81.611567  82.422090   40.274558
#
#      Continent
# 5         None
# 22        None
# 29        None
# 37        None
# 48        None
# ...        ...
# 9969      None
# 9977      None
# 9983      None
# 9986      None
# 9991      None
#
# [547 rows x 10 columns]

# %% [markdown]
# ### Add day, month, year from date to data

# %%
raw_data['Date']=pd.to_datetime(raw_data['Date'])
raw_data['day']=raw_data['Date'].dt.strftime('%d')
raw_data['month']=raw_data['Date'].dt.strftime('%m')
raw_data['year']=raw_data['Date'].dt.strftime('%Y')
raw_data.head()['day']
# Out:
# 0    01
# 1    01
# 2    02
# 3    03
# 4    04
# Name: day, dtype: object

# %%
raw_data.rename(columns={'Date':'Timestamp'}, inplace=True)
raw_data['date']=pd.to_datetime(raw_data['Timestamp']).dt.date
raw_data.head()
# Out:
#                       Timestamp          Location        Country  Temperature  \
# 0 2000-01-01 00:00:00.000000000   New Williamtown         Latvia    10.688986
# 1 2000-01-01 20:09:43.258325832      North Rachel   South Africa    13.814430
# 2 2000-01-02 16:19:26.516651665  West Williamland  French Guiana    27.323718
# 3 2000-01-03 12:29:09.774977497       South David        Vietnam    12.309581
# 4 2000-01-04 08:38:53.033303330    New Scottburgh        Moldova    13.210885
#
#    CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0     403.118903        0.717506      13.835237  23.631256   18.492026
# 1     396.663499        1.205715      40.974084  43.982946   34.249300
# 2     451.553155       -0.160783      42.697931  96.652600   34.124261
# 3     422.404983       -0.475931       5.193341  47.467938    8.554563
# 4     410.472999        1.135757      78.695280  61.789672    8.001164
#
#        Continent day month  year        date
# 0         Europe  01    01  2000  2000-01-01
# 1         Africa  01    01  2000  2000-01-01
# 2  South America  02    01  2000  2000-01-02
# 3           Asia  03    01  2000  2000-01-03
# 4         Europe  04    01  2000  2000-01-04

# %% [markdown]
# # Loading cleaned data to csv format

# %%
raw_data.to_csv('climate-cleaned.csv', index=False)
